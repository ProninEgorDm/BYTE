# %%
import polars as pl

import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np

# %%
df = pl.read_parquet('/Users/egor/VS_GIT_repositories/BYTE/src/data/tabular/yandex_realty_cleaned.csv')
df.info()

# %%
df.head()

# %%
numeric_columns = ['price_numeric', 'area', 'metro_time', 'photo_count']

category_columns = ['rooms', 'author', 'badges', 'self_floor', 'max_floor']

# %%
df[numeric_columns]

# %%
sns.pairplot(df[numeric_columns].to_pandas())

# %%
df[numeric_columns].corr
