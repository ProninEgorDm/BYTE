# %%
import polars as pl
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np

# %%
df = pd.read_parquet('/Users/egor/VS_GIT_repositories/BYTE/src/data/tabular/yandex_realty_cleaned.parquet')
df.shape
# Out:
# (30006, 22)

# %%
df.head()
# Out:
#               offer_id         price  price_numeric  old_price  area   rooms  \
# 0  7035113340557126091   7 500 000 ₽      7500000.0        NaN  17.7  студия
# 1  7035113340416809607   7 500 000 ₽      7500000.0        NaN  17.0  студия
# 2  7053956964805047621  12 200 000 ₽     12200000.0        NaN  17.9  студия
# 3  7053956914445503237   7 300 000 ₽      7300000.0        NaN  15.7  студия
# 4  3699730400767130013  10 802 031 ₽     10802031.0        NaN  14.1  студия
#
#           floor price_per_m2           metro  metro_time  ...  \
# 0  9 этаж из 16         None       Калитники         9.0  ...
# 1   2 этаж из 2         None  Соколиная гора         8.0  ...
# 2  2 этаж из 48         None       Тушинская        10.0  ...
# 3   5 этаж из 5         None       Бутырская        17.0  ...
# 4  5 этаж из 16         None      Коммунарка        14.0  ...
#
#                                           main_image photo_count badges  \
# 0  https://avatars.mds.yandex.net/get-realty-offe...         1.0   None
# 1  https://avatars.mds.yandex.net/get-realty-offe...         1.0   None
# 2  https://avatars.mds.yandex.net/get-realty-offe...         1.0   None
# 3  https://avatars.mds.yandex.net/get-realty-offe...         1.0   None
# 4  https://avatars.mds.yandex.net/get-realty-offe...         1.0   None
#
#           publish_date                                                url  \
# 0                 None  https://realty.yandex.ru/offer/703511334055712...
# 1  6 часов назад назад  https://realty.yandex.ru/offer/703511334041680...
# 2       3 квартал 2027  https://realty.yandex.ru/offer/705395696480504...
# 3  6 часов назад назад  https://realty.yandex.ru/offer/705395691444550...
# 4       2 квартал 2026  https://realty.yandex.ru/offer/369973040076713...
#
#                 title                                        description  \
# 0  апартаменты-студия  Номер лота: 99696. Панорамный вид из больших о...
# 1  апартаменты-студия  Номер лота: 87440. Продается студия с дизайнер...
# 2     квартира-студия  Арт. 119802099 Студия 17,9 м в CITYZEN Урбан-б...
# 3     квартира-студия  Арт. 134010491 СПЕЦИАЛЬНО для наших клиентов с...
# 4     квартира-студия  Строим кварталы для жизни с заботой о будущем....
#
#                                           image_urls self_floor max_floor
# 0  https://avatars.mds.yandex.net/get-realty-offe...        9.0      16.0
# 1  https://avatars.mds.yandex.net/get-realty-offe...        2.0       2.0
# 2  https://avatars.mds.yandex.net/get-realty-offe...        2.0      48.0
# 3  https://avatars.mds.yandex.net/get-realty-offe...        5.0       5.0
# 4  https://avatars.mds.yandex.net/get-realty-offe...        5.0      16.0
#
# [5 rows x 22 columns]

# %%
numeric_columns = ['price_numeric', 'area', 'metro_time', 'photo_count']

category_columns = ['rooms', 'author', 'badges', 'self_floor', 'max_floor']

# %%
sns.heatmap(df[numeric_columns].corr())
# Out:
# <Axes: >

# %%
df['title'].unique()
# Out:
# array(['апартаменты-студия', 'квартира-студия', '1-комнатные апартаменты',
#        '1-комнатная квартира', '2-комнатная квартира',
#        '2-комнатные апартаменты', '7-комнатная квартира',
#        '3-комнатная квартира', None, '1-комн. квартира',
#        '1-комн. апартаменты', '2-комн. апартаменты', '2-комн. квартира',
#        '3-комн. квартира', '3-комн. апартаменты', '5-комн. квартира',
#        '4-комн. апартаменты', '4-комн. квартира'], dtype=object)

# %%
df['metro'].nunique()
# Out:
# 338

# %%
df['author'].nunique()
# Out:
# 1643
